# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
path1 = './mask_with_index/anf_64540_01_model1_Mask_front_inspect.png'
path2 = './mask_wo_index/anf_64540_01_model1_Mask_front_inspect.png'

# %%
plt.imshow(np.array(Image.open(path1)))
plt.show()

plt.imshow(np.array(Image.open(path2)))
plt.show()

# %%
ig1 = np.array(Image.open(path1))
plt.imshow(ig1==7)
plt.show()

# %%
ig2 = np.array(Image.open(path2))
print np.unique(ig2)
# Out:
# [0 1 2 3 6]

# %%
path3 = './mask_with_index/anf_64540_01_model1.jpg'
img = np.array(Image.open(path3))
plt.imshow(img)
plt.show()

# %%
kernel = np.ones((5,5),np.uint8)
cv2.erode()
