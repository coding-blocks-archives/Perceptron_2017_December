# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
# %matplotlib inline
import cv2

# %%
## List to a numpy array
x = [1,2,3,4,5,6,7]
print type(x)
x_np = np.array(x)
print type(x_np)
x_np = np.asarray(x, dtype='uint8')

print x_np.shape
print x_np.dtype
# Out:
# <type 'list'>
# <type 'numpy.ndarray'>
# (7,)
# uint8

# %%
x_temp = np.zeros((10,2))
print x_temp.shape
x_temp2 = np.ones((15,3,2))
print x_temp2.shape

x_reshed = np.reshape(x_temp2,(-1,2))
print x_reshed.shape
# Out:
# (10, 2)
# (15, 3, 2)
# (45, 2)

# %%
x = np.random.random((10))

# %%
ig = np.random.random((225,225,3))
print ig.shape

ig2 = np.reshape(ig, (ig.shape[2], ig.shape[0], ig.shape[1]))
print ig2.shape

ig3 = np.rollaxis(ig, 2)
print ig3.shape
# Out:
# (225, 225, 3)
# (3, 225, 225)
# (3, 225, 225)

# %%
## Matplotlib
x = np.random.random((4,2))
print x.shape
plt.figure(0)

for ix in range(x.shape[0]):
    plt.scatter(x[ix,0], x[ix,1],c='red')
plt.show()
# Out:
# (4, 2)

# %%
x = np.random.random?

# %%
x = np.random.random

# %%
test_arr = np.array(range(7,17))
test_arr2 = np.array(range(3,14))
print test_arr.shape

plt.plot(test_arr,'r')
plt.plot(test_arr2)
plt.show()
# Out:
# (10,)

# %%
## OpenCV
import cv2

# %%
img = cv2.imread('/home/ayush/Downloads/cars_test/06486.jpg')
img = cv2.cvtColor(img, (cv2.COLOR_BGR2RGB))
print img.shape
print type(img)

plt.imshow(img)
plt.show()
# Out:
# (480, 640, 3)
# <type 'numpy.ndarray'>
