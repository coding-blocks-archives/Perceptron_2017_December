# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image

# %%
img_path = '../class_17/images/anf_64540_01_model1.jpg'
mask_path = '../class_17/images/anf_64540_01_model1_Mask_front_inspect.png'

# %%
img = Image.open(img_path)
print img

img2 = img.resize((512, 512))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x1200 at 0x7F59ED4F6950>

# %%
print np.array(img2).shape
# Out:
# (512, 512, 3)

# %%
img = np.array(img2)
print img.shape
plt.imshow(img)
plt.show()
# Out:
# (512, 512, 3)

# %%
mask = Image.open(mask_path)
print mask
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=512x512 at 0x7F59F0E69210>

# %%
plt.imshow(mask)
plt.show()

# %%
mask1 = np.array(mask)
print np.unique(mask, return_counts=True)
# Out:
# (array([0, 1, 2, 3, 6, 7], dtype=uint8), array([220699,   6597,  13281,  11207,    574,   9786]))

# %%
plt.imshow(np.array(mask1))
plt.show()

# %%
mask = np.reshape(mask1, (512, 512, 1))

# %%
new_img = img*(mask==2)
plt.imshow(new_img)
plt.show()
print new_img.shape
# Out:
# (512, 512, 3)
